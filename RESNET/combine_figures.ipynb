# %%
import matplotlib.pyplot as plt

# %%
val_accuracies_baseline = [
    0.96050955, 0.96585987, 0.9689172, 0.97426752, 0.9755414, 0.97528662,
    0.97273885, 0.97401274, 0.97707006, 0.97452229
]

val_accuracies_last = [
    0.90394904, 0.94802548, 0.95821656, 0.96407643, 0.96738854, 0.96738854,
    0.96815287, 0.97070064, 0.97146497, 0.97070064
]

val_accuracies_first = [
    0.9133758, 0.93121019, 0.93987261, 0.94267516, 0.94496815, 0.94496815,
    0.9444586, 0.94649682, 0.94726115, 0.94547771
]

val_accuracies_first_last = [
    0.61707006, 0.90649682, 0.92585987, 0.93121019, 0.9388535, 0.94369427,
    0.94853503, 0.94649682, 0.94802548, 0.95006369
]

val_accuracies_middle = [
    0.92127389, 0.93605096, 0.94394904, 0.94292994, 0.94394904, 0.95031847,
    0.94929936, 0.95286624, 0.95464968, 0.95388535
]

val_accuracies_first_middle_last = [
    0.42267516, 0.61656051, 0.69121019, 0.73783439, 0.77121019, 0.80789809,
    0.81656051, 0.82598726, 0.83541401, 0.84509554
]

val_accuracies_first_middle = [
    0.80076433, 0.85503185, 0.86751592, 0.89299363, 0.89732484, 0.90496815,
    0.90675159, 0.91464968, 0.91414013, 0.91363057
]

val_accuracies_middle_last = [
    0.8522293, 0.91261146, 0.92101911, 0.9322293, 0.93248408, 0.93477707,
    0.93681529, 0.9388535, 0.93936306, 0.94165605
]

plt.plot(val_accuracies_baseline, label='Baseline')
plt.plot(val_accuracies_first, label='First')
plt.plot(val_accuracies_middle, label='Middle')
plt.plot(val_accuracies_last, label='Last')
plt.plot(val_accuracies_first_last, label='First + Last')
plt.plot(val_accuracies_first_middle_last, label='First + Middle + Last')
plt.plot(val_accuracies_first_middle, label='First + Middle')
plt.plot(val_accuracies_middle_last, label='Middle + Last')
plt.title("Validation Accuracy of ResNet18 on Imagenette")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
train_loss_baseline = [
    0.51188205, 0.15761169, 0.12225144, 0.09807804, 0.08856276, 0.07908382,
    0.06997539, 0.06495493, 0.06134306, 0.05794606
]

train_loss_first = [
    1.02090434, 0.3178874, 0.22561661, 0.18578637, 0.15708537, 0.14155206,
    0.12769561, 0.12225558, 0.10791264, 0.10021103
]

train_loss_middle = [
    0.77063922, 0.27542242, 0.21393869, 0.17693373, 0.15735632, 0.14283917,
    0.12603767, 0.11874566, 0.11210647, 0.10686883
]

train_loss_last = [
    1.73917727, 0.30842882, 0.18040805, 0.13884195, 0.11517303, 0.10113398,
    0.08792255, 0.08120356, 0.07391863, 0.06833466
]

train_loss_first_last = [
    2.10528593, 0.70370505, 0.30258934, 0.22508809, 0.18937953, 0.16262637,
    0.14653334, 0.13154783, 0.11760729, 0.10627558
]

train_loss_first_middle_last = [
    2.03389404, 1.44150527, 1.11132698, 0.91811563, 0.77214179, 0.68218689,
    0.60457275, 0.55786979, 0.51489111, 0.47870814
]

train_loss_first_middle = [
    1.3214846, 0.5793276, 0.41446835, 0.34427424, 0.29788431, 0.26726125,
    0.24055761, 0.21886135, 0.20391795, 0.18227118
]

train_loss_middle_last = [
    1.92894528, 0.46948776, 0.29302451, 0.23529231, 0.20017308, 0.18314229,
    0.16065738, 0.14646894, 0.137261, 0.12921632
]

plt.plot(train_loss_baseline, label='Baseline')
plt.plot(train_loss_last, label='Last')
plt.plot(train_loss_first, label='First')
plt.plot(train_loss_first_last, label='First + Last')
plt.plot(train_loss_middle, label='Middle')
plt.plot(train_loss_first_middle_last, label='First + Middle + Last')
plt.plot(train_loss_first_middle, label='First + Middle')
plt.plot(train_loss_middle_last, label='Middle + Last')
plt.title("trainidation Loss of ResNet18 on Imagenette")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()
