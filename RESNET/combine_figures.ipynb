# %%
import matplotlib.pyplot as plt

# %%
val_accuracies_baseline = [0.97503185, 0.96968153, 0.97299363, 0.97019108, 0.9722293,  0.97375796, 0.97171975, 0.96968153, 0.97248408, 0.97146497]
val_accuracies_last = [0.82726115, 0.94878981, 0.96076433, 0.96127389, 0.96968153, 0.96968153, 0.9689172, 0.97299363, 0.97324841, 0.97146497]
val_accuracies_first = [0.91566879, 0.94216561, 0.94649682, 0.94700637, 0.9510828, 0.95261146, 0.95235669, 0.94955414, 0.95745223, 0.95617834]
val_accuracies_first_last = [0.80509554, 0.90878981, 0.9266242, 0.9289172, 0.94318471, 0.94624204, 0.94394904, 0.94802548, 0.94394904, 0.95082803]
val_accuracies_middle = [0.9355414, 0.94726115, 0.94496815, 0.95286624, 0.95261146, 0.95566879, 0.95464968, 0.95617834, 0.95566879, 0.9566879]
val_accuracies_first_middle_last = [0.63159236, 0.80101911, 0.84942675, 0.86598726, 0.88254777, 0.89146497, 0.89808917, 0.90292994, 0.90624204, 0.91159236]
val_accuracies_first_middle = [0.78624204,0.85757962,0.8743949 ,0.88152866,0.88942675,0.8955414 ,0.90369427,0.90369427,0.90853503,0.90700637]
val_accuracies_middle_last = [0.86726115, 0.90802548, 0.92458599, 0.92789809, 0.93757962, 0.94012739, 0.94165605, 0.94063694, 0.94267516, 0.9444586 ]

plt.plot(val_accuracies_baseline, label='Baseline')
plt.plot(val_accuracies_first, label='First')
plt.plot(val_accuracies_middle, label='Middle')
plt.plot(val_accuracies_last, label='Last')
plt.plot(val_accuracies_first_last, label='First + Last')
plt.plot(val_accuracies_first_middle_last, label='First + Middle + Last')
plt.plot(val_accuracies_first_middle, label='First + Middle')
plt.plot(val_accuracies_middle_last, label='Middle + Last')
plt.title("Validation Accuracy of ResNet18 on Imagenette")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
val_loss_baseline = [0.06513736, 0.06383715, 0.058279, 0.05473105, 0.04937279, 0.05049743, 0.04141252, 0.04183874, 0.04113671, 0.03865826]
val_loss_first = [0.9820845, 0.29259812, 0.20875473, 0.17178784, 0.14560405, 0.13564585, 0.12116142, 0.10686977, 0.10390461, 0.09330898]
val_loss_middle = [0.65183092, 0.17473729, 0.12008111, 0.09071527, 0.079169, 0.06343478, 0.05507333, 0.04697623, 0.04298477, 0.03832361]
val_loss_last = [2.18271724, 0.48889034, 0.19137156, 0.1465142, 0.12224789, 0.10878627, 0.09470985, 0.08422718, 0.07939796, 0.07148654]
val_loss_first_last = [1.76444899, 0.47428822, 0.27765765, 0.21541586, 0.17739616, 0.15370293, 0.1291655, 0.1124832, 0.10492717, 0.09465923]
val_loss_first_middle_last = [1.88292555, 0.87764171, 0.54563816, 0.42054031, 0.34204525, 0.29494264, 0.25797021, 0.23192509, 0.21106457, 0.18973494]
val_loss_first_middle = [1.30318365,0.56612558,0.42526904,0.34819494,0.30867443,0.27055087,0.24055042,0.2240374 ,0.20465267,0.1886672 ]
val_loss_middle_last = [1.7093145 , 0.44903004, 0.26833671, 0.21852462, 0.18718149, 0.16651809, 0.14504365, 0.13371084, 0.12509422, 0.11295853]

plt.plot(val_loss_baseline, label='Baseline')
plt.plot(val_loss_last, label='Last')
plt.plot(val_loss_first, label='First')
plt.plot(val_loss_first_last, label='First + Last')
plt.plot(val_loss_middle, label='Middle')
plt.plot(val_loss_first_middle_last, label='First + Middle + Last')
plt.plot(val_loss_first_middle, label='First + Middle')
plt.plot(val_loss_middle_last, label='Middle + Last')
plt.title("Validation Loss of ResNet18 on Imagenette")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()
